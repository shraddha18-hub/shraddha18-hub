# %% [markdown]
# <a href="https://colab.research.google.com/github/shraddha18-hub/shraddha18-hub/blob/main/Fundamental_1_Aug_Batch_(1)_(4).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 2

# %%
# import library
import pandas as pd

# %% [markdown]
# https://github.com/ybifoundation/Dataset/raw/main/Titanic.csv

# %%
titanic = pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/Titanic.csv')

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
#Read data in Colab from local drive
df = pd.read_csv('/content/Adult Salary.csv')

# %%
df.head()
# Out:
#    Age  Gender WorkingClass     Education       MaritalStatus  \
# 0   25    Male      Private          11th       Never-married
# 1   38    Male      Private       HS-grad  Married-civ-spouse
# 2   28    Male    Local-gov    Assoc-acdm  Married-civ-spouse
# 3   44    Male      Private  Some-college  Married-civ-spouse
# 4   18  Female            ?  Some-college       Never-married
#
#           Occupation Relationship   Race  NativeCountry Income
# 0  Machine-op-inspct    Own-child  Black  United-States  <=50K
# 1    Farming-fishing      Husband  White  United-States  <=50K
# 2    Protective-serv      Husband  White  United-States   >50K
# 3  Machine-op-inspct      Husband  Black  United-States   >50K
# 4                  ?    Own-child  White  United-States  <=50K

# %%
#summary statistics
titanic.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138     0.498854     0.385027
# std       0.837836     0.486055    14.413493     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
# missing values
titanic.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
#drop rows with missing values
titanic.dropna()
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %%
# random sample
titanic.sample(5)
# Out:
#       pclass  survived                             name     sex   age  sibsp  \
# 1280       3         0                  Vovk, Mr. Janko    male  22.0      0
# 1167       3         0             Sadlier, Mr. Matthew    male   NaN      0
# 825        3         0   Goodwin, Master. Harold Victor    male   9.0      5
# 1009       3         0              McMahon, Mr. Martin    male   NaN      0
# 1187       3         1  Sandstrom, Miss. Beatrice Irene  female   1.0      1
#
#       parch   ticket     fare cabin embarked boat  body  \
# 1280      0   349252   7.8958   NaN        S  NaN   NaN
# 1167      0   367655   7.7292   NaN        Q  NaN   NaN
# 825       2  CA 2144  46.9000   NaN        S  NaN   NaN
# 1009      0   370372   7.7500   NaN        Q  NaN   NaN
# 1187      1  PP 9549  16.7000    G6        S   13   NaN
#
#                                  home.dest
# 1280                                   NaN
# 1167                                   NaN
# ...

# %%
# print lable of columns
titanic.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
# extract or slice single column
single_column = titanic['name']

# %%
single_column
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %%
# extract or slice multiple columns
multiple_columns = titanic[['name', 'age', 'sex'   ]]

# %%
multiple_columns
# Out:
#                                                  name    age     sex
# 0                       Allen, Miss. Elisabeth Walton  29.00  female
# 1                      Allison, Master. Hudson Trevor   0.92    male
# 2                        Allison, Miss. Helen Loraine   2.00  female
# 3                Allison, Mr. Hudson Joshua Creighton  30.00    male
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.00  female
# ...                                               ...    ...     ...
# 1304                             Zabour, Miss. Hileni  14.50  female
# 1305                            Zabour, Miss. Thamine    NaN  female
# 1306                        Zakarian, Mr. Mapriededer  26.50    male
# 1307                              Zakarian, Mr. Ortin  27.00    male
# 1308                               Zimmerman, Mr. Leo  29.00    male
#
# [1309 rows x 3 columns]

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
#titanic.loc[rows , columns]
# titanic.loc[ :  ,  :     ] extract data in continuity
# titanic.loc[ [row1,row2 ,row3 ] : [col1 ,col2 ,col3 ,col4]]

# %%
subset_1 = titanic.loc[  10 : 15 ,  'sex' : 'fare'    ]

# %%
subset_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 10 to 15
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sex     6 non-null      object
#  1   age     5 non-null      float64
#  2   sibsp   6 non-null      int64
#  3   parch   6 non-null      int64
#  4   ticket  6 non-null      object
#  5   fare    6 non-null      float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 420.0+ bytes

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
titanic.loc[[2,4], ['fare','name', 'age' ] ]
# Out:
#      fare                                             name   age
# 2  151.55                     Allison, Miss. Helen Loraine   2.0
# 4  151.55  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.0

# %%
titanic.loc[:, ['fare','name', 'age' ] ]
# Out:
#           fare                                             name    age
# 0     211.3375                    Allen, Miss. Elisabeth Walton  29.00
# 1     151.5500                   Allison, Master. Hudson Trevor   0.92
# 2     151.5500                     Allison, Miss. Helen Loraine   2.00
# 3     151.5500             Allison, Mr. Hudson Joshua Creighton  30.00
# 4     151.5500  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.00
# ...        ...                                              ...    ...
# 1304   14.4542                             Zabour, Miss. Hileni  14.50
# 1305   14.4542                            Zabour, Miss. Thamine    NaN
# 1306    7.2250                        Zakarian, Mr. Mapriededer  26.50
# 1307    7.2250                              Zakarian, Mr. Ortin  27.00
# 1308    7.8750                               Zimmerman, Mr. Leo  29.00
#
# [1309 rows x 3 columns]

# %%
False | False
# Out:
# False

# %%
(titanic['age']<18) | (titanic['age']>60)
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 1304     True
# 1305    False
# 1306    False
# 1307    False
# 1308    False
# Name: age, Length: 1309, dtype: bool

# %%
minor_passenger = titanic[titanic['age']<18]
# Out:
#       pclass  survived                                     name     sex  \
# 1          1         1           Allison, Master. Hudson Trevor    male
# 2          1         0             Allison, Miss. Helen Loraine  female
# 53         1         0                   Carrau, Mr. Jose Pedro    male
# 54         1         1      Carter, Master. William Thornton II    male
# 55         1         1                Carter, Miss. Lucile Polk  female
# ...      ...       ...                                      ...     ...
# 1265       3         0                Van Impe, Miss. Catharina  female
# 1275       3         0          Vander Planke, Mr. Leo Edmondus    male
# 1279       3         0     Vestrom, Miss. Hulda Amanda Adolfina  female
# 1300       3         1  Yasbeck, Mrs. Antoni (Selini Alexander)  female
# 1304       3         0                     Zabour, Miss. Hileni  female
#
#         age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# ...

# %%
titanic[(titanic['age']<18) | (titanic['age']>60)]
# Out:
#       pclass  survived                                     name     sex  \
# 1          1         1           Allison, Master. Hudson Trevor    male
# 2          1         0             Allison, Miss. Helen Loraine  female
# 6          1         1        Andrews, Miss. Kornelia Theodosia  female
# 9          1         0                  Artagaveytia, Mr. Ramon    male
# 14         1         1     Barkworth, Mr. Algernon Henry Wilson    male
# ...      ...       ...                                      ...     ...
# 1265       3         0                Van Impe, Miss. Catharina  female
# 1275       3         0          Vander Planke, Mr. Leo Edmondus    male
# 1279       3         0     Vestrom, Miss. Hulda Amanda Adolfina  female
# 1300       3         1  Yasbeck, Mrs. Antoni (Selini Alexander)  female
# 1304       3         0                     Zabour, Miss. Hileni  female
#
#         age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# ...

# %% [markdown]
# # **Regression Analysis**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Step 1 : import library
import pandas as pd

# %%
# Step 2 : import data
df = pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/Admission%20Chance.csv')

# %%
df.head()
# Out:
#    Serial No  GRE Score  TOEFL Score  University Rating   SOP  LOR   CGPA  \
# 0          1        337          118                  4   4.5   4.5  9.65
# 1          2        324          107                  4   4.0   4.5  8.87
# 2          3        316          104                  3   3.0   3.5  8.00
# 3          4        322          110                  3   3.5   2.5  8.67
# 4          5        314          103                  2   2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.columns
# Out:
# Index(['Serial No', 'GRE Score', 'TOEFL Score', 'University Rating', ' SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
# Step 3 : define y and X
y = df[  'Chance of Admit '      ]
X = df[[ 'GRE Score', 'TOEFL Score', 'University Rating', ' SOP',
       'LOR ', 'CGPA', 'Research'     ]]

# %%
y.shape
# Out:
# (400,)

# %%
X.shape
# Out:
# (400, 7)

# %%
# Step 4 : split data into train and test sample
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(X,y,train_size=0.7,random_state=2529)

# %%
# Step 5 : choose the model
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# Step 6 : train model
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# -1.283124493203399

# %%
model.coef_
# Out:
# array([ 0.00204057,  0.00287273,  0.00566887, -0.00380559,  0.01973175,
#         0.11314449,  0.02061553])

# %%
# Step 7 : predict model
y_pred = model.predict(X_test)

# %%
# Step 8 : check accuracy of model
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test,y_pred)
# Out:
# 0.04400128934232659

# %% [markdown]
# # **Home Assignment : Housing price prediction**

# %% [markdown]
# y = MEDV (last column)
#
# Data link : https://github.com/ybifoundation/Dataset/raw/main/Boston.csv

# %% [markdown]
# The dataset used in this project comes from the UCI Machine Learning Repository. This data was collected in 1978 and each of the 506 entries represents aggregate information about 14 features of homes from various suburbs located in Boston.
#
# The features can be summarized as follows:
#
# - CRIM: This is the per capita crime rate by town
# - ZN: This is the proportion of residential land zoned for lots larger than 25,000 sq.ft.
# - INDUS: This is the proportion of non-retail business acres per town.
# - CHAS: This is the Charles River dummy variable (this is equal to 1 if tract bounds river; 0 otherwise)
# - NOX: This is the nitric oxides concentration (parts per 10 million)
# - RM: This is the average number of rooms per dwelling
# - AGE: This is the proportion of owner-occupied units built prior to 1940
# - DIS: This is the weighted distances to five Boston employment centers
# - RAD: This is the index of accessibility to radial highways
# - TAX: This is the full-value property-tax rate per $10,000
#
# - PTRATIO: This is the pupil-teacher ratio by town
# - B: This is calculated as 1000(Bk — 0.63)², where Bk is the proportion of people of African American descent by town
# - LSTAT: This is the percentage lower status of the population
# - MEDV: This is the median value of owner-occupied homes in $1000s

# %%
# Step 1 : import library
import pandas as pd

# %%
# Step 2 : import data
df = pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/Boston.csv')

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
# Step 3 : define y and X
y = df['MEDV']
X = df[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
       'PTRATIO', 'B', 'LSTAT']]

# %%
y.shape
# Out:
# (506,)

# %%
X.shape
# Out:
# (506, 13)

# %%
# Step 4 : Split data into train and test sample
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(X,y,train_size=0.7,random_state=2529)

# %%
# Step 5 : choose the model
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# Step 6 : train model
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 34.21916368863014

# %%
model.coef_
# Out:
# array([-1.29412069e-01,  3.65184937e-02,  1.54418944e-02,  2.35486887e+00,
#        -2.04171489e+01,  4.41356565e+00,  4.61075512e-03, -1.58626723e+00,
#         2.51478665e-01, -9.59591213e-03, -9.64169204e-01,  1.00972679e-02,
#        -5.43198745e-01])

# %%
# Step 7 : predict model
y_pred = model.predict(X_test)

# %%
# Step 8 : check accuracy of model
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test,y_pred)
# Out:
# 3.1550309276025073
